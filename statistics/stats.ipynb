# %% [markdown]
# # Describing one set of data

# %%
num_friends = [100, 49, 41, 40, 25, 100, 1, 1, 1, 1, 1, 55, 91, 36, 87, 27, 93, 76, 24, 18, 22, 37, 65, 66, 26, 80, 53, 49, 84, 68, 28, 51, 75, 63, 86, 17, 99, 11, 39, 2, 12, 48, 81, 21, 3, 57, 32, 15, 31, 35, 8, 27, 57, 69, 33, 3, 29, 9, 32, 59, 17, 31, 75, 99, 73, 47, 46, 19, 1, 80, 15, 58, 5, 16, 97, 70, 41, 49, 94, 91, 12, 48, 68, 37, 85, 67, 89, 74, 24, 53, 93, 72, 77, 14, 68, 21, 57, 83, 4, 54, 98, 18, 99, 51, 79, 84, 87, 63, 8, 61, 60, 20, 86, 40, 71, 39, 88, 91, 36, 52, 46, 96, 43, 95, 41, 76, 70, 97, 58, 34, 37, 55, 49, 45, 74, 89, 36, 58, 80, 20, 4, 78, 68, 37, 76, 7, 54, 35, 57, 82, 43, 50, 28, 71, 94, 47, 93, 11, 44, 26, 91, 25, 21, 73, 8, 99, 33, 12, 19, 23, 3, 30, 6, 98, 59, 90, 1, 64, 70, 15, 29, 48, 16, 97, 92, 67, 41, 46, 39, 56, 95, 34, 87, 5, 62, 61, 81, 38, 17, 96, 63, 79, 27, 10, 85, 65, 22, 9, 77, 42, 60, 52, 86, 69, 32, 75, 100, 51, 66, 83, 88, 40, 53, 24, 84, 14, 72, 18, 31, 2, 13, 47, 67, 55, 99, 42, 64, 84, 90, 58, 73, 91, 92, 63, 83, 56, 60, 79, 43, 59, 96, 82, 67, 86, 49, 93, 65, 80, 83, 79, 74, 91, 96, 90, 97, 71, 42, 64, 72, 55, 100]

# %%
len(num_friends)
# Out:
# 271

# %%
# Histogram
from collections import Counter
import matplotlib.pyplot as plt

friend_counts = Counter(num_friends)
xs = range(101)                         # Largest value is 100
ys = [friend_counts[x] for x in xs]     # height is just # of friends

plt.bar(xs, ys)
plt.axis([0, 101, 0, 25])
plt.title("Histogram of friend counts")
plt.xlabel("# of friends")
plt.ylabel("# of people")
plt.show();

# %%
# Largest and smallest values
max(num_friends)
# Out:
# 100

# %%
min(num_friends)
# Out:
# 1

# %%
sorted(num_friends)
# Out:
# [1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  3,
#  3,
#  3,
#  4,
#  4,
#  5,
#  5,
#  6,
#  7,
#  8,
#  8,
#  8,
#  9,
#  9,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  13,
#  14,
#  14,
#  15,
#  15,
#  15,
#  16,
#  16,
#  17,
#  17,
#  17,
#  18,
#  18,
#  18,
#  19,
#  19,
#  20,
#  20,
#  21,
#  21,
#  21,
#  22,
#  22,
#  23,
#  24,
#  24,
#  24,
#  25,
#  25,
#  26,
#  26,
#  27,
#  27,
#  27,
#  28,
#  28,
#  29,
#  29,
#  30,
#  31,
#  31,
#  31,
#  32,
#  32,
#  32,
#  33,
#  33,
#  34,
#  34,
#  35,
#  35,
#  36,
#  36,
#  36,
#  37,
#  37,
#  37,
#  37,
#  38,
#  39,
#  39,
#  39,
#  40,
#  40,
#  40,
#  41,
#  41,
#  41,
#  41,
#  42,
#  42,
#  42,
#  43,
#  43,
#  43,
#  44,
#  45,
#  46,
#  46,
#  46,
#  47,
#  47,
#  47,
#  48,
#  48,
#  48,
#  49,
#  49,
#  49,
#  49,
#  49,
#  50,
#  51,
#  51,
#  51,
#  52,
#  52,
#  53,
#  53,
#  53,
#  54,
#  54,
#  55,
#  55,
#  55,
#  55,
#  56,
#  56,
#  57,
#  57,
#  57,
#  57,
#  58,
#  58,
#  58,
#  58,
#  59,
# ...
